# %% [markdown]
# # 03 関数とクラス: Functions and Classes

# %%
# 学籍番号: 
# 氏名:

# %% [markdown]
# ## 課題
# 引数として与えられたリスト`data`から、その最小要素`v`とそのインデックス`i`を返す関数`find_min`を作成し、動作を確認しなさい。
#
# Create a function `find_min` that takes a list `data` as an argument and returns the minimum element `v` and its index `i`. Verify its operation.
